# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding='latin-1')

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
# number 1 
# (B)

# %%
# number 2
# (A)

# %%
# number 3
# (E)

# %%
# 4
df['Area'].nunique()
# Out:
# 49

# %% [markdown]
# Ans = B

# %%
# 5
df2 = df[df['Area'] == 'Madagascar']
df2[df2['Element'] == 'Protein supply quantity (g/capita/day)'].sum()
# Out:
# Area Code                                                   14319
# Area            MadagascarMadagascarMadagascarMadagascarMadaga...
# Item Code                                                  299405
# Item            Grand TotalVegetal ProductsAnimal ProductsCere...
# Element Code                                                74814
# Element         Protein supply quantity (g/capita/day)Protein ...
# Unit            g/capita/dayg/capita/dayg/capita/dayg/capita/d...
# Y2014                                                      177.79
# Y2015                                                      173.05
# Y2016                                                       173.4
# Y2017                                                      175.75
# Y2018                                                      176.64
# dtype: object

# %%
#6
df3 = df[df.Element == 'Processing']
df3.Y2017.sum()
# ans = d
# Out:
# 292836.0

# %% [markdown]
# Ans = A

# %%
# 
no_of_missing = df.Y2014.isnull().sum()
perc_missing = (no_of_missing/df.Y2014.shape)*100
perc_missing = perc_missing.round(3)
print(no_of_missing, perc_missing)
# Out:
# 1589 [2.607]

# %% [markdown]
# Ans = E

# %%
# Out:
# 49

# %%
# num  7
df.corr()
# answer = c
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
df2 = df[df['Area'] == 'Madagascar']
df2[df2['Element'] == 'Protein supply quantity (g/capita/day)'].sum()

# ans = A
# Out:
# Area Code                                                   14319
# Area            MadagascarMadagascarMadagascarMadagascarMadaga...
# Item Code                                                  299405
# Item            Grand TotalVegetal ProductsAnimal ProductsCere...
# Element Code                                                74814
# Element         Protein supply quantity (g/capita/day)Protein ...
# Unit            g/capita/dayg/capita/dayg/capita/dayg/capita/d...
# Y2014                                                      177.79
# Y2015                                                      173.05
# Y2016                                                       173.4
# Y2017                                                      175.75
# Y2018                                                      176.64
# dtype: object

# %%
# num 8
y = [(2, 4), (7, 8), (1, 5, 9)]

x = y[1][1]
x

#ans = c
# Out:
# 8

# %%
# num 9
my_tuppy = (1,2,5,8)

my_tuppy[2] = 6

# ans = b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-ce1543b3be47> in <module>
#       1 my_tuppy = (1,2,5,8)
#       2
# ----> 3 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
 # num 10
df4 = df[['Y2017','Area']]
df4.groupby('Area').sum()

# ans = c
# Out:
#                                   Y2017
# Area
# Algeria                       325644.27
# Angola                        229159.57
# Benin                         124771.22
# Botswana                       22101.30
# Burkina Faso                  101855.07
# Cabo Verde                     14650.74
# Cameroon                      232030.43
# Central African Republic       29937.00
# Chad                           71594.68
# Comoros                           59.84
# Congo                          41181.68
# Côte d'Ivoire                 224599.01
# Djibouti                       22729.91
# Egypt                         866379.92
# Eswatini                       54343.33
# Ethiopia                      448683.76
# Ethiopia PDR                       0.00
# Gabon                          27979.64
# Gambia                         23154.18
# Ghana                         337599.06
# Guinea                         98138.87
# Guinea-Bissau                  19102.77
# ...

# %%
# num 11
df.shape
#answer = b
# Out:
# (60943, 12)

# %%
# num 12
x = set([2,5,64,4,6])
x[3]
# set is unordered
# ans = b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-9e7281b89730> in <module>
#       1 x = set([2,5,64,4,6])
# ----> 2 x[3]
#
# TypeError: 'set' object is not subscriptable

# %%
# num 13
df5 = df[df['Element'] == 'Stock Variation'].max()
df5
#ans = D
# Out:
# Area Code                   276
# Area                   Zimbabwe
# Item Code                  2961
# Item                       Yams
# Element Code               5072
# Element         Stock Variation
# Unit                1000 tonnes
# Y2014                      4569
# Y2015                      3418
# Y2016                      3266
# Y2017                      5089
# Y2018                      2226
# dtype: object

# %%
# num 14
S = [['him', 'sell'], [90, 28, 43]]

S[0][1][1]
#ans  = d
# Out:
# 'e'

# %%
# num 15
df.describe().round(2)
# ans = A
# Out:
#        Area Code  Item Code  Element Code      Y2014      Y2015      Y2016  \
# count   60943.00   60943.00      60943.00   59354.00   59395.00   59408.00
# mean      134.27    2687.18       3814.86     134.20     135.24     136.56
# std        72.61     146.06       2212.01    1567.66    1603.40    1640.01
# min         4.00    2501.00        511.00   -1796.00   -3161.00   -3225.00
# 25%        74.00    2562.00        684.00       0.00       0.00       0.00
# 50%       136.00    2630.00       5142.00       0.09       0.08       0.08
# 75%       195.00    2775.00       5511.00       8.34       8.46       8.43
# max       276.00    2961.00       5911.00  176405.00  181137.00  185960.00
#
#            Y2017      Y2018
# count   59437.00   59507.00
# mean      140.92     143.76
# std      1671.86    1710.78
# min     -1582.00   -3396.00
# 25%         0.00       0.00
# 50%         0.10       0.07
# 75%         9.00       9.00
# max    190873.00  195875.00

# %%
# num 15
import math
#ans = B

# %%
#num 18 
df6 = df[['Y2017', 'Area']]
df6.groupby("Area").sum().max()
# ans = C
# Out:
# Y2017    1483268.23
# dtype: float64

# %%
#num 19
array = np.array([[94, 89, 63],

             [93, 92, 48],

             [92, 94, 56]])
array[ : 2, 1 : ] 
# ans = e
# Out:
# array([[89, 63],
#        [92, 48]])

# %%
#num 20
# ans = A and E
